# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Dataset
data = {
      'tinggi': [150,160,170,155,165,175,180,158,168,172],
    'berat':  [45,55,65,50,60,70,80,52,62,68],
    'kategori': ['kurus','ideal','ideal','kurus','ideal','gemuk','gemuk','kurus','ideal','ideal']
}


df = pd.DataFrame(data)

# Fitur & target
X = df[['tinggi','berat']]
y = df['kategori']

# Normalisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.3, random_state=42
)


# Model KNN
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)

# Prediksi
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.3333333333333333

# %% [markdown]
# Model KNN dapat digunakan untuk klasifikasi kategori tubuh, namun performa model masih terbatas karena jumlah data yang sedikit. Untuk mendapatkan hasil yang lebih akurat, diperlukan data yang lebih banyak dan beragam.

# %%
print("y_test:", y_test.values)
print("y_pred:", y_pred)
# Out:
# y_test: ['ideal' 'ideal' 'gemuk']
# y_pred: ['ideal' 'kurus' 'ideal']
